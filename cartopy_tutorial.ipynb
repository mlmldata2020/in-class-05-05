# %% [markdown]
# ## Mapping in Python with Cartopy
#
# Check out a gallery of different maps at:
# https://scitools.org.uk/cartopy/docs/latest/gallery/index.html

# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %% [markdown]
# #### Plate Carree
#
# The Plate Carree (flat plate) projection is the most basic. It simply maps longitude values to the x coordinate and latitude values to the y coordinate.

# %% [markdown]
# #### Mercator

# %% [markdown]
# #### Lambert conformal

# %% [markdown]
# ### Projection list
#
# A list of projections available in Cartopy can be found here: http://scitools.org.uk/cartopy/docs/v0.15/crs/projections.html#

# %% [markdown]
# ### Adding latitude and longitude ticks

# %%
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

plt.figure()
ax = plt.axes(projection=ccrs.Mercator())
gl = ax.gridlines(draw_labels=True)
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
ax.coastlines()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# The `make_map` function in the `maptools.py` module can be used to execute this code auotmatically.

# %%
from maptools import make_map # requires maptools.py!

plt.figure()
ax = make_map(ccrs.Mercator())
ax.coastlines()

# %% [markdown]
# ### Mapping Monterey Bay

# %%
# map extent for Monterey Bay
extent = [-122.3, -121.6, 36.5, 37.1]

# %% [markdown]
# #### High-resolution coastline

# %% [markdown]
# #### Tiles

# %% [markdown]
# #### Bathy
#
# The `coastal_relief_model` directory contains bathymetry data for Monterey Bay. The `load_crm_asc` function in the `maptools.py` module can be used to load this data set.

# %%
from maptools import load_crm_asc
help(load_crm_asc)
# Out:
# Help on function load_crm_asc in module maptools:
#
# load_crm_asc(data_file)
#     Load bathymetry data from NOAA Coastal Relief model data set.
#     For data in ascii format generated at:
#     http://maps.ngdc.noaa.gov/viewers/wcs-client/
#
#     Returns:
#     z: m x n array of elevation values (negative for depth in ocean, positive on land)
#     lon: array of n longitude values
#     lat: array of m latitude values
#
#     Tom Connolly, MLML (3/2016)

# %%
z,lon,lat = load_crm_asc('coastal_relief_model/crm-montereybay.asc')

# %% [markdown]
# ### Elkhorn Slough shapefiles

# %% [markdown]
# http://www.elkhornslough.org/gis/index.htm
#
# The files are in the following coordinate system:  `UTM Zone 10 WGS84`

# %%
ls Elkhorn_Slough_GIS/CZ/
# Out:
# cz.dbf  cz.shp  cz.shx

# %%
from cartopy.io import shapereader

# %% [markdown]
# #### Exercises
#
# * Create a map where the extent is better suited to Elkhorn Slough
# * Plot the roads in `Elkhorn_Slough_GIS/ROADS` directory
# * Create a map showing the sample locations for your final project, using an appropriate projection (not Plate Carree, unless your project is on the equator).
